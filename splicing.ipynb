# %%
from splicing import splicing

# %%
splicing("SLC22A5")
# Out:
# ['NM_003060.4:c.393+2T>G',
#  'NM_003060.4:c.394-2A>G',
#  'NM_003060.4:c.393+1G>A',
#  'NM_003060.4:c.393+2T>A',
#  'NM_003060.4:c.394-1G>A',
#  'NM_003060.4:c.393+1G>T',
#  'NM_003060.4:c.394-2A>T',
#  'NM_003060.4:c.394-1G>T',
#  'NM_003060.4:c.393+1G>C',
#  'NM_003060.4:c.393+2T>C',
#  'NM_003060.4:c.394-2A>C',
#  'NM_003060.4:c.394-1G>C',
#  'NM_003060.4:c.497+2T>G',
#  'NM_003060.4:c.498-2A>G',
#  'NM_003060.4:c.497+1G>A',
#  'NM_003060.4:c.497+2T>A',
#  'NM_003060.4:c.498-1G>A',
#  'NM_003060.4:c.497+1G>T',
#  'NM_003060.4:c.498-2A>T',
#  'NM_003060.4:c.498-1G>T',
#  'NM_003060.4:c.497+1G>C',
#  'NM_003060.4:c.497+2T>C',
#  'NM_003060.4:c.498-2A>C',
#  'NM_003060.4:c.498-1G>C',
#  'NM_003060.4:c.652+2T>G',
#  'NM_003060.4:c.653-2A>G',
#  'NM_003060.4:c.652+1G>A',
#  'NM_003060.4:c.652+2T>A',
#  'NM_003060.4:c.653-1G>A',
#  'NM_003060.4:c.652+1G>T',
#  'NM_003060.4:c.653-2A>T',
#  'NM_003060.4:c.653-1G>T',
#  'NM_003060.4:c.652+1G>C',
#  'NM_003060.4:c.652+2T>C',
# ...

# %%
splicing("ADAMTS13")
# Out:
# ['NM_139027.6:c.105+2T>G',
#  'NM_139027.6:c.106-2A>G',
#  'NM_139027.6:c.105+1G>A',
#  'NM_139027.6:c.105+2T>A',
#  'NM_139027.6:c.106-1G>A',
#  'NM_139027.6:c.105+1G>T',
#  'NM_139027.6:c.106-2A>T',
#  'NM_139027.6:c.106-1G>T',
#  'NM_139027.6:c.105+1G>C',
#  'NM_139027.6:c.105+2T>C',
#  'NM_139027.6:c.106-2A>C',
#  'NM_139027.6:c.106-1G>C',
#  'NM_139027.6:c.172+2T>G',
#  'NM_139027.6:c.173-2A>G',
#  'NM_139027.6:c.172+1G>A',
#  'NM_139027.6:c.172+2T>A',
#  'NM_139027.6:c.173-1G>A',
#  'NM_139027.6:c.172+1G>T',
#  'NM_139027.6:c.173-2A>T',
#  'NM_139027.6:c.173-1G>T',
#  'NM_139027.6:c.172+1G>C',
#  'NM_139027.6:c.172+2T>C',
#  'NM_139027.6:c.173-2A>C',
#  'NM_139027.6:c.173-1G>C',
#  'NM_139027.6:c.330+2T>G',
#  'NM_139027.6:c.331-2A>G',
#  'NM_139027.6:c.330+1G>A',
#  'NM_139027.6:c.330+2T>A',
#  'NM_139027.6:c.331-1G>A',
#  'NM_139027.6:c.330+1G>T',
#  'NM_139027.6:c.331-2A>T',
#  'NM_139027.6:c.331-1G>T',
#  'NM_139027.6:c.330+1G>C',
#  'NM_139027.6:c.330+2T>C',
# ...

# %%
splicing("TMPRSS6")
# Out:
# ['NM_001374504.1:c.-2+2T>G',
#  'NM_001374504.1:c.-1-2A>G',
#  'NM_001374504.1:c.-2+1G>A',
#  'NM_001374504.1:c.-2+2T>A',
#  'NM_001374504.1:c.-1-1G>A',
#  'NM_001374504.1:c.-2+1G>T',
#  'NM_001374504.1:c.-1-2A>T',
#  'NM_001374504.1:c.-1-1G>T',
#  'NM_001374504.1:c.-2+1G>C',
#  'NM_001374504.1:c.-2+2T>C',
#  'NM_001374504.1:c.-1-2A>C',
#  'NM_001374504.1:c.-1-1G>C',
#  'NM_001374504.1:c.202+2T>G',
#  'NM_001374504.1:c.203-2A>G',
#  'NM_001374504.1:c.202+1G>A',
#  'NM_001374504.1:c.202+2T>A',
#  'NM_001374504.1:c.203-1G>A',
#  'NM_001374504.1:c.202+1G>T',
#  'NM_001374504.1:c.203-2A>T',
#  'NM_001374504.1:c.203-1G>T',
#  'NM_001374504.1:c.202+1G>C',
#  'NM_001374504.1:c.202+2T>C',
#  'NM_001374504.1:c.203-2A>C',
#  'NM_001374504.1:c.203-1G>C',
#  'NM_001374504.1:c.336+2T>G',
#  'NM_001374504.1:c.337-2A>G',
#  'NM_001374504.1:c.336+1G>A',
#  'NM_001374504.1:c.336+2T>A',
#  'NM_001374504.1:c.337-1G>A',
#  'NM_001374504.1:c.336+1G>T',
#  'NM_001374504.1:c.337-2A>T',
# ...
