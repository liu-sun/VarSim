# %%
import pprint

from variationsimulation import simulate

# %%
pprint.pprint(simulate("SLC22A5"))
# Out:
# [('NM_003060.4:c.2T>A', 'NP_003051.1:p.M1K'),
#  ('NM_003060.4:c.3G>A', 'NP_003051.1:p.M1I'),
#  ('NM_003060.4:c.1A>T', 'NP_003051.1:p.M1L'),
#  ('NM_003060.4:c.3G>T', 'NP_003051.1:p.M1I'),
#  ('NM_003060.4:c.1A>C', 'NP_003051.1:p.M1L'),
#  ('NM_003060.4:c.2T>C', 'NP_003051.1:p.M1T'),
#  ('NM_003060.4:c.3G>C', 'NP_003051.1:p.M1I'),
#  ('NM_003060.4:c.1A>G', 'NP_003051.1:p.M1V'),
#  ('NM_003060.4:c.2T>G', 'NP_003051.1:p.M1R'),
#  ('NM_003060.4:c.4C>A', 'NP_003051.1:p.R2R'),
#  ('NM_003060.4:c.5G>A', 'NP_003051.1:p.R2Q'),
#  ('NM_003060.4:c.6G>A', 'NP_003051.1:p.R2R'),
#  ('NM_003060.4:c.4C>T', 'NP_003051.1:p.R2W'),
#  ('NM_003060.4:c.5G>T', 'NP_003051.1:p.R2L'),
#  ('NM_003060.4:c.6G>T', 'NP_003051.1:p.R2R'),
#  ('NM_003060.4:c.5G>C', 'NP_003051.1:p.R2P'),
#  ('NM_003060.4:c.6G>C', 'NP_003051.1:p.R2R'),
#  ('NM_003060.4:c.4C>G', 'NP_003051.1:p.R2G'),
#  ('NM_003060.4:c.7G>A', 'NP_003051.1:p.D3N'),
#  ('NM_003060.4:c.9C>A', 'NP_003051.1:p.D3E'),
# ...
